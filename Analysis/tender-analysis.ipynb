# %%
import pandas as pd
import glob
import os

# %%
bihar_tenders = pd.read_csv(r'D:\CivicDataLab_IDS-DRR\IDS-DRR_Github\Deployment\flood-data-ecosystem-Bihar\Sources\TENDERS\tender_data_csv\all_tenders_bihar.csv')
bihar_tenders
# Out:
#       tenderid                           tenderrefno  \
# 0        18397                 31/BCD/MUNGER/2021-22
# 1        18398  BSMCL-08/2021-22/VAISHALI/CLUSTER-03
# 2        18399  BSMCL-08/2021-22/VAISHALI/CLUSTER-04
# 3        18400     BSMCL-08/2021-22/BANKA/CLUSTER-02
# 4        18401               01/2021-22 MID, Nalanda
# ...        ...                                   ...
# 3894     53628                     06/2023-24 (G-19)
# 3895     53629                     06/2023-24 (G-20)
# 3896     53630                     06/2023-24 (G-21)
# 3897     53631                     06/2023-24 (G-22)
# 3898     53632                     06/2023-24 (G-23)
#
#                                                   title  \
# 0     FURNITURE WORK FOR GOVERNMENT ENGINEERING COLL...
# 1     EC Approved Sand Ghat of VAISHALI (Cluster-03)...
# 2     EC Approved Sand Ghat of VAISHALI (Cluster-04)...
# 3     EC APPROVED SANDGHATS OF BANKA (CLUSTER-02)\nP...
# ...

# %%
total_value = bihar_tenders['procurement_amount_pacamt'].sum()
total_value
# Out:
# 56103517831.060005

# %%
up_tenders = up_tenders.loc[up_tenders['Status'] == 'Accepted-AOC']
up_tenders
# Out:
#       Unnamed: 0            Tender ID  \
# 0            794  2021_CEBBS_65546_30
# 5           2286    2021_RWSS_70806_2
# 39          3451   2022_CEBBS_84530_5
# 78           438  2021_CELBB_66256_15
# 100          506    2021_IDCO_65684_1
# ...          ...                  ...
# 4099        3014   2022_CCEJE_82163_1
# 4103        3098    2022_OBCC_82729_4
# 4105        3356   2022_CEBMB_81568_6
# 4113        3830  2021_CEBMB_68091_55
# 4115        3892   2022_CCEJE_83477_1
#
#                       tender_externalreference  \
# 0     Bid Identification No. EE-AID-12-2020-21
# 5                04/SE/RWSS/ANGUL/2021-22(JJM)
# 39                            SE-AID-6/2022-23
# 78                         EEPRD-20 OF 2020-21
# 100                        PC/EST/E-59/2020-21
# ...                                        ...
# 4099                  SEUKID 01/2022-23 (SL 5)
# 4103                   NO.42/TOLL/OBCC/2022-23
# 4105                        ACE,RBB-20/2022-23
# ...
