# %%
import pandas as pd
import geopandas as gpd
import numpy as np

# %%
up_villages = gpd.read_file('/Users/saurabhlevin/Deployment/flood-data-ecosystem-UP/Maps/up_ids-drr_shapefiles/UP_Villages_Boundary_Simplified.geojson')

# %%
up_villages = up_villages.drop(columns=['geometry','remark', 'ac_no', 'search_village',
       'st_length(shape)', 'st_area(shape)' ])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 up_villages = up_villages.drop(columns=['geometry','remark', 'ac_no', 'search_village',
#       2        'st_length(shape)', 'st_area(shape)' ])
#
# NameError: name 'up_villages' is not defined

# %%
up_villages.to_csv('/Users/saurabhlevin/Deployment/flood-data-ecosystem-UP/Maps/up_ids-drr_shapefiles/UP_VILLAGES.csv', index=False
                   )

# %% [markdown]
# ### Convert shapefile CRS

# %%
up_dt = gpd.read_file(r'D:\CivicDataLab_IDS-DRR\IDS-DRR_Github\Deployment\flood-data-ecosystem-UP\Maps\up_ids-drr_shapefiles\UP_district_final.geojson')

# %%
import geopandas as gpd

# 1. Read your “meter‐based” GeoJSON
gdf = gpd.read_file(r"D:\CivicDataLab_IDS-DRR\IDS-DRR_Github\Deployment\flood-data-ecosystem-Bihar\Maps\br-ids-drr_shapefile\Bihar_District_Boundary_final.geojson")

# 2. Tell GeoPandas it’s in Web Mercator
gdf = gdf.set_crs(epsg=3857)

# 3. Reproject to WGS84 (lat/lon)
gdf = gdf.to_crs(epsg=4326)

# 4. Save out a new GeoJSON with decimal‐degree coords
gdf.to_file(r"D:\CivicDataLab_IDS-DRR\IDS-DRR_Github\Deployment\flood-data-ecosystem-Bihar\Maps\br-ids-drr_shapefile\Bihar_district_final_4326.geojson", driver="GeoJSON")

# %% [markdown]
# ### Create district object-id reference

# %%
bihar_sdt = gpd.read_file(r'D:\CivicDataLab_IDS-DRR\IDS-DRR_Github\Deployment\flood-data-ecosystem-Bihar\Maps\br-ids-drr_shapefile\Bihar_subdistrict_final_4326.geojson')

# %%
bihar_sdt
# Out:
#         object_id stname              dtname                    sdtname  \
# 0    10-206-01064  BIHAR           Sitamarhi                      Suppi
# 1    10-234-01463  BIHAR              Rohtas                  Nasriganj
# 2    10-234-01464  BIHAR              Rohtas                     Rajpur
# 3    10-234-01465  BIHAR              Rohtas                  Sanjhauli
# 4    10-203-01023  BIHAR  Pashchim Champaran                  Thakrahan
# ..            ...    ...                 ...                        ...
# 528  10-239-01541  BIHAR           Jehanabad                  Hulasganj
# 529  10-240-01545  BIHAR               Arwal  Sonbhadra Banshi Suryapur
# 530  10-240-01546  BIHAR               Arwal                     Kurtha
# 531  10-224-01334  BIHAR           Bhagalpur                   Gopalpur
# 532  10-210-01127  BIHAR          Kishanganj                 Kishanganj
#
#      st_area_sh  st_length_ remarks  dist_lgd  state_lgd  subdt_lgd ac_no  \
# ...

# %%
# create the district geojson
bihar_district = bihar_sdt.dissolve(by='dtname', as_index=False)

# %%
bihar_district.to_file(r'D:\CivicDataLab_IDS-DRR\IDS-DRR_Github\Deployment\flood-data-ecosystem-Bihar\Maps\br-ids-drr_shapefile\Bihar_district_final_4326.geojson')
bihar_district['object-id'] = bihar_district['object_id'].str[:6]

# %%
bihar_district_asset = bihar_district[['object-id','dtname']]
bihar_district_asset.to_csv(r'D:\CivicDataLab_IDS-DRR\IDS-DRR_Github\Deployment\IDS-DRR-Bihar-Risk-Score-Model\RiskScoreModel\assets\district_objectid.csv')
